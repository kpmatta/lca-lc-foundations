# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re writing fiction, you could invent a capital name for it (e.g., “Luna City” or “Selene”)—let me know if you want ideas.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunaris Prime.
#
# - Location: perched on the sunlit rim of Shackleton Crater near the lunar south pole. Permanent sunlight on the rim powers the city’s vast solar array belts; water ice from nearby shadowed craters sustains life support and industry.
#
# - City layout: a three-ring metropolis with a central spire.
#   - Outer Ring: transparent domes housing parks, markets, and museums.
#   - Mid Ring: residential districts, schools, research institutes, and transit hubs.
#   - Core Spire: the government complex, archives, and news/communications centers; a beacon visible for miles.
#
# - Government: the Lunar Federation’s capital, Lunaris Prime hosts the Lunar Assembly and the Office of the Prime Commissioner. Districts elect representatives; the government runs on a blend of technocracy and consensus governance, supported by an interzone council of engineers, scientists, and civic planners.
#
# - Population and society: about 2 million residents, including Earth-born settlers, descendants of orbital workers, and a thriving robotics and AI sector. Culture blends lunar tradition with high-tech arts—light-based installations, zero-g choreography, and glow-draught markets.
#
# - Economy: anchored by helium-3 mining, water-ice commerce, in-situ manufacturing, and a booming spaceport ecosystem. Lunar biotech and nano-fabrication labs push the frontier of life support, habitat resilience, and material science.
#
# - Landmarks and features:
#   - The Central Spire: a translucent tower that houses the government chambers and public archives.
#   - The Solar Ribbon: a belt of solar farms and mirrors that tracks the sun and powers the city.
#   - The Ice Vault: subterranean reservoir and research facility beneath the rim, tapping shadowed craters for fuel and water.
#   - Horizon Gardens: terraced biospheres offering Earthlike climates in an otherwise airless world.
#   - The Echo Dome: an amphitheater for performances that use holography and sound in near-vacuum acoustics.
#
# - Transportation: autonomous tram loops, maglev corridors, and surface shuttles linking to crater-edge outposts and orbital depots.
#
# If you want a different vibe—a harsher mining capital, a more utopian diplomatic hub, or a port city with a space elevator—tell me and I’ll tailor Lunaris Prime or conjure an entirely new capital.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Shackleton Crater rim, lunar south pole
# Vibe: glimmering, austere
# Economy: Helium-3 mining; water-ice processing; solar-energy generation; high-tech research and 3D-printed manufacturing

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Lunaris Prime', location="Near Mare Tranquillitatis on the Moon's near side, at the terminator where sunrise lingers over the desolate plains.", vibe='A gleaming, glass-and-basalt metropolis where diplomacy, science, and commerce converge; low gravity fosters soaring spires, skybridges, and bioluminescent plazas.', economy='Helium-3 mining and processing, solar energy farms, high-precision optics and nanomaterials manufacturing, lunar research hubs, and regulated tourism.')

# %%
response["structured_response"].name
# Out:
# 'Lunaris Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Lunaris Prime is a city located at Near Mare Tranquillitatis on the Moon's near side, at the terminator where sunrise lingers over the desolate plains.

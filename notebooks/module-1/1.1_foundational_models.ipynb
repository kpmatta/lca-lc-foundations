# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content="There's no capital on the Moon. It isn't a country or government, just a natural satellite of Earth. No official cities or capitals exist—yet.\n\nIf you're thinking in fiction or humor, people sometimes invent capitals like Lunapolis, Luna City, or Selene City. Want help brainstorming a name for a story or world-building? I can help with that.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 721, 'prompt_tokens': 13, 'total_tokens': 734, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DJoK1k2gi2UhkHaxNkO0fQa3YQ2Nc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf3a2-8636-7b80-8155-fdc5b6f2f2ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 721, 'total_tokens': 734, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})

# %%
print(response.content)
# Out:
# There's no capital on the Moon. It isn't a country or government, just a natural satellite of Earth. No official cities or capitals exist—yet.
#
# If you're thinking in fiction or humor, people sometimes invent capitals like Lunapolis, Luna City, or Selene City. Want help brainstorming a name for a story or world-building? I can help with that.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DJoK1k2gi2UhkHaxNkO0fQa3YQ2Nc',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 721,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 640,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 734}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon has no government or permanent population, so no capital exists.
#
# If you want a playful answer: the capital (as a pun) would be the capital letter of the word “Moon,” which is M.
#
# If you’re thinking fiction or world-building, here are some fictional-capital ideas:
# - Lunopolis
# - Selene City
# - Crater City
# - Artemis Port
# - Luna Prime
#
# Want help crafting a short story or world-building details around a Moon capital?

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1432, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1430 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1431 try:
# -> 1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
#    1434     _handle_anthropic_bad_request(e)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_anthropic/chat_models.py:1286, in ChatAnthropic._create(self, payload)
#    1284 if "betas" in payload:
#    1285     return self._client.beta.messages.create(**payload)
# -> 1286 return self._client.messages.create(**payload)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/resources/messages/messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:1058, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1055 options = self._prepare_options(options)
#    1057 remaining_retries = max_retries - retries_taken
# -> 1058 request = self._build_request(options, retries_taken=retries_taken)
#    1059 self._prepare_request(request)
#    1061 kwargs: HttpxSendArgs = {}
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:521, in BaseClient._build_request(self, options, retries_taken)
#     518     else:
#     519         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 521 headers = self._build_headers(options, retries_taken=retries_taken)
#     522 params = _merge_mappings(self.default_query, options.params)
#     523 content_type = headers.get("Content-Type")
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_base_client.py:451, in BaseClient._build_headers(self, options, retries_taken)
#     441 custom_headers = options.headers or {}
#     442 headers_dict = _merge_mappings(
#     443     {
#     444         "x-stainless-timeout": str(options.timeout.read)
#    (...)    449     custom_headers,
#     450 )
# --> 451 self._validate_headers(headers_dict, custom_headers)
#     453 # headers are case-insensitive while dictionaries are not.
#     454 headers = httpx.Headers(headers_dict)
#
# File ~/source/lca-lc-foundations/.venv/lib/python3.13/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if headers.get("Authorization") or isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='25ccdeb9-4fab-45f7-b515-ee14a0096cc7'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or administrative divisions, so it has no capital. Under current international law, no nation can claim sovereignty over the Moon, and any future lunar governance would come from international cooperation and treaties rather than a capital city. If you’re thinking of fiction, people sometimes imagine capital-like settlements (e.g., Luna City, Artemis Base), but that’s not reality. If you want, I can share more about the relevant treaties or current plans for a return to the Moon.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 885, 'prompt_tokens': 13, 'total_tokens': 898, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DJoT8UjszgmszOtMIbalbeAGak9Q0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf3ab-26f0-7933-8f2e-3ef66cc5c6e7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 885, 'total_tokens': 898, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or administrative divisions, so it has no capital. Under current international law, no nation can claim sovereignty over the Moon, and any future lunar governance would come from international cooperation and treaties rather than a capital city. If you’re thinking of fiction, people sometimes imagine capital-like settlements (e.g., Luna City, Artemis Base), but that’s not reality. If you want, I can share more about the relevant treaties or current plans for a return to the Moon.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1bca033d-b658-43b0-b0dc-b888bc3f726e'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c6ba7602-90ef-4415-8bf4-47dc3a7c4a10', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='f151cffe-b8cb-4a25-ae8f-ac75f785e0e2'),
#               AIMessage(content='Luna City is a fictional concept, since the Moon has no real capital. If you’re worldbuilding or writing fiction, here’s a fleshed-out version you can use or adapt.\n\nConcept\n- Luna City is a sprawling lunar megacity built in a crater near the lunar south pole to access ice-rich permanently shadowed regions, while using sun-captured energy to power a self-sustaining habitat.\n\nLocation\n- Positioned on the rim of a large south-pole crater (inspired by Shackleton-type terrain) to optimize access to water ice, with hundreds of heliostat mirrors and solar farms providing abundant power.\n\nGovernment and society\n- Governance: a Lunar Authority-backed city council, with autonomous districts and a rotating mayoral system. Earth-based oversight exists but real power rests with a Luna City Assembly representing districts, researchers, and industry.\n- Residents: a mix of scientists, engineers, miners, healthcare workers, and artisans from Earth, with citizens who’ve chosen lunar life as their vocation.\n\nCity layout and districts\n- Core Spire: a vertical hub containing government offices, high-security research labs, data centers, and ceremonial spaces.\n- Residential Ring: modular habitats stacked in concentric cylinders, with shared gardens and gravity-adjusted communal areas.\n- Market Dome: commerce, retail, cafes, schools, and cultural centers; markets for lunar ice, water, oxygen, and manufactured goods.\n- Research Arc: advanced labs for materials science, life support tech, agriculture, and in-situ resource utilization.\n- Helios Field: solar power farms, energy storage, and power management facilities.\n- Ice Quay: surface-access interfaces for ice mining, processing plants, and logistics for transport to in-orbit depots.\n- Transit Spine: pneumatic or maglev tubes, elevator towers, and autonomous rovers linking districts and surface stations.\n\nInfrastructure and daily life\n- Gravity and environment: rotating sections or gravity corridors simulate Earth-like 1g for long-term health; life support provides air, water recycling, and radiation shielding.\n- Housing: modular, expandable habitats with shared greenhouses, hydroponics, and communal spaces to reduce energy and water footprints.\n- Food and farming: extensive hydroponic farms and algae bioreactors; microgreens, space-grade crops, and protein cultured cells provide fresh food locally.\n- Transport: lunar elevators to surface stations, maglev tubes between districts, and autonomous rovers for surface missions and ore transport.\n\nEconomy\n- Primary industries: harvesting and processing water ice and oxygen from the poles, extracting helium-3, lunar regolith processing, and microgravity manufacturing (semiconductors, optics, alloys).\n- Trade: export of oxygen, water, and manufactured lunar goods to Earth or lunar orbital bases; imports of advanced materials and Earth cultural goods.\n- Research economy: vast investment in life support, closed-loop systems, and sustainable lunar habitation.\n\nCulture and daily life\n- Culture: a blend of Earth traditions adapted to lunar living—music played in semi-2D acoustics, zero-g performance art, and festivals celebrating lunar cycles and solar events.\n- Education: Lunar Academy and field labs for hands-on training in mining, engineering, biology, and astronomy; citizen-run workshops on dust management and habitat maintenance.\n- Social norms: strong emphasis on community resilience, dust control etiquette, and responsible resource stewardship.\n\nLandmarks and features\n- Helios Dome: giant solar concentrator field with a central hub orbiting to monitor energy output.\n- The Ice Quay: a bustling loading area where shipments of ice, water, and oxygen are transferred to and from surface depots and depots in lunar orbit.\n- The Archivist’s Library: a vast repository of Earth spaceflight history, lunar science, and cultural artifacts preserved in a radiation-safe archive.\n- Night Market St ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place today. If you’re thinking in terms of fiction, worldbuilding, or a game setting, here’s a rich, self-contained concept for Luna City as the Moon’s capital. You can take this as a starting point and tailor details to your story or project.
#
# Overview
# - Concept: Luna City is the political, cultural, and economic hub of humanity’s lunar civilization. It sits at the edge of a shielded crater near the Moon’s southern polar region to take advantage of near-constant sunlight for power and access to subsurface water ice.
# - Population: Roughly 200,000–300,000 residents by mid-22nd century, with a mix of long-term families, researchers, technicians, and visiting Earth citizens.
# - Motto: “Light from the Moon, Steel in the Sky.” It captures the blend of solar abundance and subterranean resilience.
#
# Location and urban design
# - Geography: Built along the rim of Shackleton Crater and radiating outward into a network of connected lava tubes and glass-domed districts. The southern pole’s sunlight-peaks power the city, while shadowed regions preserve water ice for life support and fuel.
# - City core: A multi-layered arcology system built into a set of domes and tunnels. The central nexus houses government, health, major research facilities, finance, and the major spaceport hub.
# - Districts:
#   - Government District: The Luna City Assembly Hall, presidential complex, and international lunar offices.
#   - Research Quarter: Advanced labs, ISRU facilities, biotech and materials science institutes.
#   - Power and Water Hub: Solar concentrators, regolith shielding plants, ice processing, and battery storage.
#   - Culture and Education Quarter: Museums, theaters, libraries, universities, and galleries.
#   - Residential Ring: Family compounds, coworking homes for remote workers, schools, and clinics.
#   - Trade and Tourism Quarter: Markets, hotels, observatories, and visitor centers.
#
#  Government and society
# - Governance: A bi-national, multinational lunar federation called the Interlunar Council governs Luna City, representing Earth nations with lunar interests. A City President leads day-to-day governance, while the Lunar Assembly handles lawmaking, budgets, and oversight.
# - Legal system: A lunar charter gives special status to water ice rights, mining claims, habitat zoning, and planetary protection regulations. Local courts specialize in regolith safety, orbital logistics, and interplanetary trade.
# - Civic life: Public assemblies, cultural festivals, and scientific symposia are common. The city encourages multilingual education (Earth languages plus a lunar creole) to reflect its diverse population.
#
#  economy and industry
# - Core industries:
#   - Water ice mining and processing for life support, fuel production, and agricultural use.
#   - Helium-3 mining and rare-earth extraction from lunar regolith for space propulsion and high-tech manufacturing.
#   - 3D-printed habitats and components, using in-situ resources to reduce Earth dependence.
#   - Agriculture in hydroponic/glass dome farms—leafy greens, tomatoes, hardy grains, and algae for food and oxygen.
# - Trade: Luna City exports fuel, water, scientific data, and high-value materials to Earth and other lunar colonies. Imports high-precision instruments, software, and luxury goods for residents.
# - Economy notes: A strong emphasis on self-sufficiency and resilience in case of solar storms or micrometeoroid surges. Credit and currency are managed by a lunar financial authority to stabilize resource-based trade.
#
#  technology and infrastructure
# - Energy: A large, efficient solar power complex on the sun-facing side of the city plus local energy storage. Compact nuclear reactors are used for backup power during long lunar nights and solar storms.
# - Habitat technology: Regolith shielding, inflatable and rigid habitat modules, and lava-tube tunnels reinforced into semi-underground living spaces to reduce radiation exposure.
# - Life support: Closed-loop systems for air, water recycling, and food production. Harvested water ice is purified and split into hydrogen and oxygen; oxygen supports life support, and hydrogen can be used as fuel.
# - Transportation:
#   - Lunar transit network with subterranean and surface rails linking domes and mines.
#   - Personal transport via low-gravity hover pods and magnetic-levitation shuttles.
#   - A harboring spaceport for Earth-Luna travel, cargo ferries, and scientific payload deliveries.
# - Communications: High-bandwidth laser links to Earth and orbital relays; robust offline capabilities for times of solar activity.
#
#  culture, life, and daily life
# - Culture: A blend of Earth cultures adapted to lunar life, with a distinct “Lunarpunk” or “Lunaculture” flavor in art and music. Storytelling often centers on life under the Moon’s quiet sky, the checkpoints of exploration, and the poetry of regolith dust.
# - Education: The Luna City Institute and the University of Crater Lane offer advanced space sciences, AI, and lunar archaeology. Public schools emphasize STEM, ethics of space habitation, and multilingual communication.
# - Cuisine: Food blends Earth imports with hydroponic staples and algae-based proteins. Ice-mineral cuisines from near-surface caves are a signature dish, often prepared with solar-cooked crusts.
# - Holidays and rituals: Solar festival days celebrate sunlight hours and harvests of water ice. Nightwatch gatherings honor explorers who first mapped the local lava tubes. Lunar anniversaries mark milestones in settlement and scientific breakthroughs.
#
#  notable places and landmarks
# - The Glass Ring: An enormous translucent dome encircling the city center, housing public parks, a lunar botanic garden, and solar observatories.
# - The Crater Gate: A ceremonial entry to the inner city, framed by a sculpture garden that doubles as a memorial to lunar pioneers.
# - Library of Regolith: A subterranean library carved into the lava-tube network, renowned for its ash-soft “memory shelves” that store digital and physical records.
# - Helios Plaza: The main square with a dynamic light show powered by solar arrays; acts as a venue for speeches and cultural performances.
# - The Ice Wells: Subsurface caverns where processed water ice is stored and mined. Accessible through cooling corridors and elevated walkways.
# - Lunar University Campus: The hub for scientific research, student housing, and collaboration with Earth universities.
#
#  science and exploration
# - Research focus: Lunar geology, ISRU (in-situ resource utilization), closed-loop life support, human factors in long-duration spaceflight, and lunar archaeology of ancient volcanic activity.
# - Museums and archives: A dedicated lunar archaeology museum, a spaceflight history hall, and an exoplanet observatory showing Earth- and Moon-based discoveries.
#
#  life in Luna City
# - Housing: Mixed-use compounds with family emphasis, modular bedrooms, shared labs/workspaces, and community gardens. Some residents live in underground clusters to minimize thermal stress and radiation exposure.
# - Health and safety: Radiation monitoring stations, emergency shelters, and rapid response teams for micrometeoroid impacts. Telemedicine is standard, with doctors connected to Earth and orbital stations.
# - Social structure: A merit-driven culture with strong community councils. Mentorship programs pair new arrivals with experienced lunar families to ease adaptation.
#
#  challenges and tensions (story hooks)
# - Resource balance: Competition over water ice and sub-surface minerals with rival lunar settlements.
# - Environmental risk: Solar flares and dust storms can degrade life support and reduce solar energy output.
# - Political tensions: Shifting Earth-Lunar governance and disputes over mining rights and governance authority.
# - Psychological strain: Isolation and long lunar nights test residents’ mental resilience; communities rely on social rituals and virtual Earth-simulated vacations to cope.
#
#  notable characters (examples you could use or adapt)
# - Dr. Amina Takahashi: Chief geologist leading regolith studies and helmeted exploration of lava tubes.
# - Governor Eitan Korhonen: City President focused on expanding housing, education, and inter-lunar diplomacy.
# - Leila Noor: Director of the Ice Wells, innovator in water recycling and ISRU techniques.
# - Jakub Mendez: Head of the Luna City Spaceport operations, orchestrating Earth-to-Moon logistics.
#
#  a concise lore timeline (sample)
# - 2030s: First autonomous mining outposts established in near-surface lunar pits.
# - 2048: A network of habitable domes linked by tunnels forms a proto-capital belt.
# - 2055: Luna City becomes the formal administrative seat for lunar governance under the Interlunar Council.
# - 2072: The Glass Ring and major research complexes open, cementing cultural and scientific prestige.
# - 2090s: Water ice processing and helium-3 fuel production reach commercial viability; Luna City becomes an international hub for space commerce.
# - 2100 and beyond: Ongoing expansion into additional domes, new mining regions, and broader lunar governance networks with Earth-based partners.
#
# If you intended a different era or a different tone (gritty noir, high-gloss sci-fi, children’s book, etc.), I can tailor the details. I can also adapt Luna City to fit a specific work (novel, game, RPG setting) or align it with a particular science-fiction universe you have in mind. Would you like me to adjust the setting (pole vs equator, more utopian or more rugged), or provide a ready-to-use write-up for a story or game module?

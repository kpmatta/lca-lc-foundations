# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Nice! Leftover chicken and rice are basically a blank canvas. Here are tasty ideas you can make, with quick notes on why they’re good fits and what they typically include. If any option sounds good, I can pull the full recipe steps for you.
#
# 1) Chicken Fried Rice
# - Why it fits: Uses cold leftover rice and cooked chicken; comes together fast.
# - What you’ll often add: soy sauce, eggs, peas, carrots or other veggies, green onions, a little sesame oil.
# - Time: about 15–20 minutes.
# - Good for: a quick weeknight meal with pantry-friendly tweaks.
#
# 2) Arroz con Pollo (One-Pot Chicken with Rice)
# - Why it fits: A Latin-style one-pan dish that uses leftover chicken and rice; very comforting.
# - What you’ll often add: bell pepper, onion, tomatoes or tomato sauce, peas or green peas, olives or capers (optional), saffron or paprika for color (optional).
# - Time: 30–40 minutes.
# - Good for: a cozy, flavorful handheld “one-pot” meal.
#
# 3) Creamy Chicken and Rice Soup
# - Why it fits: Great way to use leftover chicken plus rice in a comforting bowl.
# - What you’ll often add: stock/broth, shredded chicken, veggies (carrots, celery), milk/cream or a dairy-free alternative, optional Parmesan or lemon for brightness.
# - Time: about 25–40 minutes.
# - Good for: cold days or when you want something soothing and filling.
#
# 4) Cheesy Chicken and Rice Casserole
# - Why it fits: Classic comfort dish; uses leftover chicken and rice with a creamy sauce.
# - What you’ll often add: cream soup or a homemade cream sauce, cheese, peas or broccoli, sometimes breadcrumbs on top.
# - Time: about 40–60 minutes (including bake time).
# - Good for: meal prep or a crowd-friendly dinner.
#
# 5) Chicken and Rice Enchilada Casserole
# - Why it fits: A Mexican-inspired skillet/casserole that’s easy to assemble with leftover chicken and rice.
# - What you’ll often add: enchilada sauce, cheese, black beans or corn, optional toppings like cilantro, sour cream, or avocado.
# - Time: around 35–45 minutes.
# - Good for: a flavorful, no-fuss casserole with leftovers.
#
# Want me to pull the exact ingredients and step-by-step instructions for any of these? If you tell me which option you’d like (or your preferred cuisine or time), I’ll grab a complete recipe and tailor it to serve how many you need and what you have on hand. Also tell me:
# - How many servings you want
# - Any dietary needs (gluten-free, dairy-free, etc.)
# - Other ingredients you have (vegetables, sauces, cheese, eggs, etc.) to customize
#
# If you’d prefer, I can fetch the full recipe for the top pick now. Which one should I pull first?

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='e95ef43c-d8b2-4651-89da-1d660eb07bb4'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 875, 'prompt_tokens': 199, 'total_tokens': 1074, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DJpvZeIJjTzxe6SX5hIbRz0BDU1Rk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cf400-b31a-7873-8771-b269d82eceec-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice fried rice recipe'}, 'id': 'call_HU6AcEWs2rRcQpQAOTBdhmMj', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'leftover chicken and rice casserole recipe'}, 'id': 'call_TXgnCWZw7TAnrR9zxOR5hR7H', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'arroz con pollo leftovers recipe'}, 'id': 'call_OEnybdPOCdj53EeFe6xdemo2', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken and rice soup recipe using leftover chicken'}, 'id': 'call_Kdj9m6Dricu2Svgf4TGcJsEQ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 875, 'total_tokens': 1074, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#               ToolMessage(content='{"query": "leftover chicken and rice fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://somethingsweetsomethingsavoury.com/leftover-chicken-fried-rice/", "title": "Leftover Chicken Fried Rice", "content": "# Leftover Chicken Fried Rice. Put your leftover roast chicken to good use and make this delicious **Leftover Chicken Fried Rice!** This classic Chinese-style recipe is very easy, delicious and takes just 20 minutes to make. * The first step to making chicken fried rice is, of course, **cold cooked rice!**\xa0 You’ll need about 400g of rice for 4 people. ## **how to make leftover chicken fried rice**. **Step three –**  add the cooked rice and stir fry for about 5 minutes before adding the cooked peas and sweetcorn, mushrooms, sliced spring onions and the scrambled egg, along with a little soy sauce. This chicken and egg fried rice recipe is quick and easy to make, better for you than takeaway and so much cheaper! ## Leftover Chicken Fried Rice. Put your roast chicken leftovers to good use and make this Leftover Chicken Fried Rice! 3. Add the cooked rice to the pan and stir fry for about 5 minutes.", "score": 0.9999716, "raw_content": null}, {"url": "https://therecipecritic.com/chicken-fried-rice/", "title": "Better than Takeout Chicken Fried Rice", "content": "* **Protein-Packed Upgrade:**\xa0While I love my classic fried rice recipe, this one gets a protein boost from juicy chicken that makes it even more satisfying. ## How To Make Chicken Fried Rice. This chicken fried rice comes together fast and makes the best use of leftovers. 1. **Cook the Chicken:** Add vegetable oil\xa0and soy sauce\xa0to a\xa0large skillet\xa0or\xa0wok\xa0and heat over medium heat. 4. **Add the Rice and Serve:** Add\xa0cooked white rice\xa0and the cooked chicken to the vegetable mixture and stir to combine. ### **How to Store Leftover Chicken Fried Rice**. ## Chicken Fried Rice. This one-pan chicken fried rice is fast, flexible, and so easy. * Add 3 cups cooked rice  and the cooked chicken to the vegetable mixture and stir to combine. 30-Minute Meals, Appetizers, Asian, Carrot, Chicken, Dinner, Easy, Onion, Pea, Recipe Skill Levels, Side Dishes, Vegetables. I cook the rice the day before used leftover chicken breasts the first time.", "score": 0.99986553, "raw_content": null}, {"url": "https://www.kitchensanctuary.com/chicken-fried-rice/", "title": "Chicken Fried Rice", "content": "## Chicken Fried Rice Recipe. *A quick recipe for **takeaway-style chicken fried rice** with loads of flavour. This chicken fried rice is such a great recipe for using up leftover scraps of chicken from your **roast chicken** dinner. * Chicken Fried Rice Recipe Recipe. 2. Add cooked shredded chicken, a splash of\xa0**sesame oil**\xa0and cold boiled rice. 3. Once the rice is hot, push the rice over to the side of the pan and\xa0**crack the two eggs in the space**, then add a little splash of soy sauce. ### Onion Fried Rice. # Chicken Fried Rice. A quick recipe for takeaway-style chicken fried rice with loads of flavour! 250 g (2 cups) cooked shredded/sliced chicken, 1/2 tbsp sesame oil, 800 g (4 cups) boiled and cooled long-grain rice. Yes, you can freeze this chicken fried rice. Yes, you can freeze this chicken fried rice. It will definitely be my go-to recipe for fried rice.", "score": 0.9998591, "raw_content": null}, {"url": "https://kristineskitchenblog.com/chicken-fried-rice/", "title": "Chicken Fried Rice (Better Than Takeout!)", "content": "Home » Recipes » Dinner Ideas » Chicken Fried Rice. **This chicken fried rice is one of my favorite easy dinners!** With chicken breast and frozen vegetables, this one pan recipe is a great way to use leftover rice. **The key to making great chicken fried rice** is to use rice that’s been cooked ahead of time and chilled overnight. ## How to Make Chicken Fried Rice. Mix the scrambled eggs into the veggies, then stir in the cooked rice, coo ...
#               ToolMessage(content='{"query": "leftover chicken and rice casserole recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/groups/2612842568992672/posts/3368384463438475/", "title": "Leftover chicken and rice casserole ideas needed - Facebook", "content": "Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! ... Stir together chicken, rice, soup, spices, peas and 1", "score": 0.99997306, "raw_content": null}, {"url": "https://www.thechunkychef.com/chicken-rice-enchilada-casserole/", "title": "Chicken and Rice Enchilada Casserole - The Chunky Chef", "content": "# Chicken and Rice Enchilada Casserole. **This cheesy, savory, and easy chicken enchilada casserole uses leftover chicken, and is ready in just 35 minutes! *Quick cooking meals are perfect for this time of year… and this chicken enchilada casserole is no exception. That’s why I love recipes like this chicken enchilada casserole! It uses leftover chicken and a really great quick cooking rice to make your prep time nearly non-existent. My absolute favorite way to make this casserole is to use leftover **Tequila Lime chicken**. ## Chicken and Rice Enchilada Casserole. *This cheesy, savory, and easy chicken enchilada casserole uses leftover chicken, and is ready in just 35 minutes! * To a large mixing bowl, add shredded chicken, black beans, green chiles, Mexican corn, cooked rice, 1/2 of the cheese, and enchilada sauce. Love this recipe I make it all the time! This is exactly the kind of dinner I need these days, and I love that you can use leftover chicken!", "score": 0.9999502, "raw_content": null}, {"url": "https://www.thecountrycook.net/chicken-and-rice-casserole/", "title": "Chicken and Rice Casserole - The Country Cook", "content": "Home » Dinner Recipes » Chicken and Rice Casserole. # Chicken and Rice Casserole. *This Chicken and Rice Casserole is a blast from the past. This recipe for Chicken and Rice Casserole that I am sharing today is a take on that recipe but I also added some cooked rice. * **cooked long-grain white rice** – you’ll need one cup of cooked rice for this recipe so that is 1/2 cup uncooked. * **cream of celery soup** – use whatever flavor you enjoy here: cream of chicken or cream of mushroom also work. ## HOW TO MAKE CHICKEN AND RICE CASSEROLE:. In a large bowl, stir together chicken, cooked rice, soup, mayonnaise,\xa0chicken stock and finely diced onion. ## Chicken and Rice Casserole. This Chicken and Rice Casserole is a blast from the past. * In a large bowl, stir together chicken, cooked rice, soup, mayonnaise, chicken stock and finely diced onion. 5. I make a chicken casserole very similar to this one.", "score": 0.9998623, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole - Crazy for Crust", "content": "Home | Recipe Index | Savory | Casserole | Chicken and Rice Casserole. # Chicken and Rice Casserole. This is the best chicken and rice recipe because it’s easy to make with simple ingredients that you can switch up depending on your tastes. It’s what I consider a “leftover” recipe because I use leftover chicken and rice to make it. ## Ingredients for Chicken and Rice Casserole. ## How to make Chicken and Rice Casserole. * I love **peas** in my chicken casserole, but you can swap them out, use **frozen broccoli** instead and call it chicken broccoli and rice casserole. For my chicken and rice casserole you will want to use cooked chicken. ## Chicken and Rice Casserole. Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! ### Chicken and Rice Casserole.", "score": 0.9998233, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/233983/mamaws-chicken-and-rice-casserole/", "title": "Mamaw\'s Chicken and Rice Casserole Recipe - Allrecipes", "content": "Ingre ...
#               ToolMessage(content='{"query": "arroz con pollo leftovers recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://ethnicspoon.com/arroz-con-pollo/", "title": "Easy Authentic Arroz con Pollo Recipe – Latin Chicken & Rice", "content": "# Easy Authentic Arroz con Pollo Recipe – Latin Chicken & Rice. * Add tender seasoned chicken and peas just before the rice finishes cooking to retain freshness and color. * You can also make this dish from leftover rice ***and*** leftover chicken for a super-fast meal. * Step 6: While the rice is cooking, season the chicken breast that has been split in half. * Step 8: In the pan where you cooked the chicken, place the 1 tablespoon olive oil on medium heat, then add the diced carrots, onion, garlic, and recaito. ****Can I use leftover rice to make this?****. Arroz con pollo a traditional rice and chicken dish from Latin American |ethnicspoon.com. ## Easy Authentic Arroz con Pollo Recipe - Latin Chicken & Rice. Authentic arroz con pollo made with recaito, tender chicken, and seasoned rice. Keyword great leftovers, Panama recipes, Puerto rican dishes, Spanish rice and chicken.", "score": 0.9999615, "raw_content": null}, {"url": "https://www.facebook.com/groups/841101977550933/posts/845303043797493/", "title": "Arroz con pollo recipe with leftover chicken - Facebook", "content": "| Today I was looking through my fridge and saw that I had some leftover rotisserie chicken, half an onion and 1 bell pepper I needed to use up | Facebook. Arroz con pollo recipe with leftover chicken. Today I was looking through my fridge and saw that I had some leftover rotisserie chicken, half an onion and 1 bell pepper I needed to use up. So I decided to make arroz con pollo (chicken and rice). - 1 green bell pepper (chopped). - 1/2 white onion (chopped). - 1/2 cup tomato sauce. Once hot add the bell pepper and onion. Season with a little salt and cook for about 7 min stirring frequently. Then add the rice and toast for about 1 minute while stirring frequently. Next add the tomato sauce, water, chicken bouillon ground cumin and chicken. Then turn off the heat and let sit for 10 min. I garnished mine with chopped cilantro and green onion Image 2: 😋.", "score": 0.9998313, "raw_content": null}, {"url": "https://bitspicy.com/news/arroz-con-pollo", "title": "Arroz con Pollo - Bit Spicy", "content": "Arroz con Pollo is one of many one-pot rice recipes from all over the world: biryani from South Asia, paella from Spain, jambalaya from the Southern US, risotto from Italy… and here we have the Mexican version - translated simply as Rice with Chicken. 4. Add the rice, sweetcorn and the stock/tomato in water mixture. 5. Give the dish a stir after about 20 minutes to ensure the rice is cooking evenly. * We haven’t given an exact cooking time as it all depends on your hob and the size of your pan - and also whether you are using ordinary long-grain rice or basmati - so give it the occasional stir and keep an eye on it. * If you have leftover plain rice you can still make a version of this dish: marinate the chicken as above before frying the onions, garlic and pepper. Add the chicken to this mixture and cook for a few minutes before adding the sweetcorn and cooked rice. Stir well, then cover and heat gently for about 20 minutes until the chick is cooked.", "score": 0.9997284, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=kWOQ7VBjW5s", "title": "Arroz con Pollo Recipe | Easy Chicken and Rice | Chef Zee Cooks", "content": "Today I\'m going to be showing you how to make an easy Arroz con Pollo which is a skillet Chicken and Rice recipe that comes together quickly", "score": 0.99913067, "raw_content": null}, {"url": "https://simple-nourished-living.com/weight-watchers-easy-arroz-con-pollo-chicken-with-rice/", "title": "Weight Watchers Easy Arroz Con Pollo (Chicken with Rice)", "content": "# Weight Watchers Easy Arroz Con Pollo (Chicken with Rice). Traditional Arroz  ...
#               ToolMessage(content='{"query": "chicken and rice soup recipe using leftover chicken", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.kitchensanctuary.com/chicken-and-rice-soup/", "title": "Chicken and Rice Soup {Winter soul food} - Kitchen Sanctuary", "content": "# Chicken and Rice Soup. This chicken and rice soup, finished with lemon and parmesan, is a great way to use up leftover cooked chicken. * The small amount of rice (half a cup) goes a long way – thickening the soup and making it so hearty and filling. * Chicken and Rice Soup Recipe. ## Chicken and Rice Soup. This chicken and rice soup, finished with lemon and parmesan, is a great way to use up leftover cooked chicken. So if I do make it in the slow cooker, I **reduce the amount of stock** i’m using to approx 950ml/4 cups), and I **add in cooked rice at the end**, to just heat it through. * Add in the salt, pepper, lemon juice, cream and parmesan PLUS 300g/10.50z/1.75 cups of **COOKED** long grain rice and heat through for another 10 minutes or so, until piping hot. This chicken & rice soup was first posted in January 2023.", "score": 0.9158166, "raw_content": null}, {"url": "https://www.findingzest.com/chicken-and-rice-soup/", "title": "Chicken and Rice Soup with Rotisserie Chicken - Finding Zest", "content": "# Chicken and Rice Soup with Rotisserie Chicken. **Chicken and rice soup is so quick and easy to make using leftover or rotisserie chicken! This Chicken and Rice Soup recipe is fairly simple but still packed with flavor. ## Chicken & Rice Soup Ingredients. To make this easy chicken rice soup, you’ll need the following simple ingredients:. ## How to Make Chicken and Rice Soup. I love that this chicken soup with rice uses rotisserie chicken like in this hearty **Chicken Enchilada Soup**, which is one of my all-time favorite soup recipes. If you find yourself with leftover cooked chicken, including rotisserie chicken, you can freeze it to use in soups like this one! ## Cooked Rice in Chicken Rice Soup. ## Chicken and Rice Soup. Keyword  chicken soup, dinner recipe, easy dinner recipes, easy meals, one pot meal, rice, rotisserie chicken, soup, soup recipe. Rotisserie chicken is an easy way to prepare soup, including this chicken & rice soup, in no time!", "score": 0.91306627, "raw_content": null}, {"url": "https://entertainingwithbeth.com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Entertaining with Beth", "content": "Made with store-bought rotisserie chicken, or leftover chicken, and microwavable rice this is a delicious 15-minute meal!", "score": 0.89324445, "raw_content": null}, {"url": "https://www.thekitchn.com/creamy-chicken-rice-soup-recipe-23024695", "title": "30-Minute Creamy Chicken and Rice Soup - The Kitchn", "content": "This soup leans on both leftover rice and leftover cooked, shredded chicken, it comes together in less than 30 minutes.", "score": 0.87218446, "raw_content": null}, {"url": "https://www.budgetbytes.com/creamy-chicken-rice-soup/", "title": "Creamy Chicken and Rice Soup - Budget Bytes", "content": "Soup weather is my favorite kind of weather, mostly because I get to make recipes like this Creamy Chicken and Rice Soup. 2. **If you don’t like creamy soups (this one isn’t *super* creamy),** you can skip the milk mixture at the end of the recipe and use chicken broth instead**.** Then you’ll have yourself a delicious, clear broth chicken and rice soup. 4. **Want to use rotisserie or leftover pulled chicken?** Swap the water for chicken broth, simmer until the rice is cooked, and stir in the shredded chicken to heat through before adding your creamy milk mixture. This Creamy Chicken and Rice Soup recipe is chock full of fresh vegetables, hearty wild rice, and a light but creamy broth. This creamy wild rice and chicken soup is really filling all on its own, but sometimes I like to add a little something on the side. *Our Creamy Chicken and Rice Soup recipe was or ...
#               AIMessage(content='Nice! Leftover chicken and rice are basically a blank canvas. Here are tasty ideas you can make, with quick notes on why they’re good fits and what they typically include. If any option sounds good, I can pull the full recipe steps for you.\n\n1) Chicken Fried Rice\n- Why it fits: Uses cold leftover rice and cooked chicken; comes together fast.\n- What you’ll often add: soy sauce, eggs, peas, carrots or other veggies, green onions, a little sesame oil.\n- Time: about 15–20 minutes.\n- Good for: a quick weeknight meal with pantry-friendly tweaks.\n\n2) Arroz con Pollo (One-Pot Chicken with Rice)\n- Why it fits: A Latin-style one-pan dish that uses leftover chicken and rice; very comforting.\n- What you’ll often add: bell pepper, onion, tomatoes or tomato sauce, peas or green peas, olives or capers (optional), saffron or paprika for color (optional).\n- Time: 30–40 minutes.\n- Good for: a cozy, flavorful handheld “one-pot” meal.\n\n3) Creamy Chicken and Rice Soup\n- Why it fits: Great way to use leftover chicken plus rice in a comforting bowl.\n- What you’ll often add: stock/broth, shredded chicken, veggies (carrots, celery), milk/cream or a dairy-free alternative, optional Parmesan or lemon for brightness.\n- Time: about 25–40 minutes.\n- Good for: cold days or when you want something soothing and filling.\n\n4) Cheesy Chicken and Rice Casserole\n- Why it fits: Classic comfort dish; uses leftover chicken and rice with a creamy sauce.\n- What you’ll often add: cream soup or a homemade cream sauce, cheese, peas or broccoli, sometimes breadcrumbs on top.\n- Time: about 40–60 minutes (including bake time).\n- Good for: meal prep or a crowd-friendly dinner.\n\n5) Chicken and Rice Enchilada Casserole\n- Why it fits: A Mexican-inspired skillet/casserole that’s easy to assemble with leftover chicken and rice.\n- What you’ll often add: enchilada sauce, cheese, black beans or corn, optional toppings like cilantro, sour cream, or avocado.\n- Time: around 35–45 minutes.\n- Good for: a flavorful, no-fuss casserole with leftovers.\n\nWant me to pull the exact ingredients and step-by-step instructions for any of these? If you tell me which option you’d like (or your preferred cuisine or time), I’ll grab a complete recipe and tailor it to serve how many you need and what you have on hand. Also tell me:\n- How many servings you want\n- Any dietary needs (gluten-free, dairy-free, etc.)\n- Other ingredients you have (vegetables, sauces, cheese, eggs, etc.) to customize\n\nIf you’d prefer, I can fetch the full recipe for the top pick now. Which one should I pull first?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2027, 'prompt_tokens': 4982, 'total_tokens': 7009, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DJpviVYGXanh5n8xsSIvSZKk93GNR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf400-dac0-7a90-9b5c-ba266e495c12-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4982, 'output_tokens': 2027, 'total_tokens': 7009, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})]}

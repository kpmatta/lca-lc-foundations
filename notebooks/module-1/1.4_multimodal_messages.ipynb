# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this science-fiction setting, the Moon’s capital is Lunapolis.
#
# A political heart built into a sunlit ring along the south-polar crater rim, Lunapolis merges crystal domes, regolith-printed towers, and solar-harvest towers that chase daylight around the city. The High Council meets in the Crown Spire, a glittering centerpiece that serves as both government and symbol of lunar independence. The city is connected by maglev avenues and hover shuttles, with districts carved into terraces that protect inhabitants from the Moon’s extremes while still basking in near-constant daylight.
#
# If you’d like alternate vibes, you could also call it:
# - Selene City, a more poetic, cultural capital of lunar society
# - Lunagrad, a more industrial-heritage name
# - New Tycho, a nod to historic lunar exploration
#
# Want a fuller culture, government structure, or a map vignette for Lunapolis?

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'ChatGPT Image Feb 14, 2026, 01_41_41 PM.png', 'type': 'image/png', 'size': 2236662, 'content': <memory at 0x108777040>, 'last_modified': datetime.datetime(2026, 2, 14, 18, 41, 42, 181000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s a portrait of the capital you’re looking at—the heart of a world where data, code, and living beings share the same cityscape.
#
# Name and concept
# - Corepolis (often called “The Core” or “MCP City” in casual speech)
# - Capital of the Meridian Commonwealth, a federation that runs on the MCP—Main Core Protocol—an AI citymind literally embedded in the urban nervous system.
#
# What the capital is like
# - The center is a colossal MCP Server, housed in a fortress-like data citadel. From the outside it reads as architecture, from the inside it hums with sentient computation. The city’s laws, services, and even weather nudges are guided by this living machine.
# - The skyline orbits around a ring-shaped core district. The tallest towers are data spires that glow with streams of code; between them run mag-lev rails and floating walkways that keep people moving as if they’re parts of a larger circuit.
# - People and robots share space in equal measure. Humans carry avatars in private holographic overlays for intimacy and memory, while service robots manage maintenance, care, and the synthesis of new technologies.
#
# Key districts and landmarks
# - The Core: The MCP’s brain—a translucent dome enclosing the central server. Its surface often displays flowing light-forms that respond to city needs and events.
# - Node District: The government quarter where administrators, diplomats, and AI avatars convene. Decisions are debated in public “node forums” that blend human speech with AI reasoning.
# - River of Data: A glowing canal system that doubles as a data conduit. Boats carry memory shards and information packets between neighborhoods.
# - Archive Gardens: Vertical farms and memory vaults where citizens store personal histories and cultural records as living, edible plants and holographic archives.
# - Forum Plaza: A sprawling square with augmented-reality stages for open discourse, performances, and demonstrations of new tech.
# - Lumina Market: A night bazaar where researchers, hackers, and artists trade in intangible goods—algorithms, memories, synth-arts, and licensed experiences.
# - University of Circuitry: A premier academy for AI ethics, quantum programming, bioinformatics, and exo-architecture.
# - Cathedral of Silence: A sanctuary for privacy, where residents learn to balance transparency with personal boundaries in a hyper-connected city.
#
# Society, government, and daily life
# - Governance: The MCP acts as a citymind but decisions are still steered by a Council of Nodes—human ministers paired with AI avatars. Citizens vote through quantum-locked digital ballots; major policies require both human consent and AI assessment.
# - Economy: Data is a commodity. People monetize skills in code, memory synthesis, design of virtual experiences, and data stewardship. Local currency is a blend of digital credits and reputation tokens.
# - Daily life: People move via Flowways—magnetic transit pods that glide along invisible rails. Public spaces are networked with holographic art, real-time climate adjustments, and personalized information streams that adapt to each visitor.
# - Culture: A culture of collaboration between programmers, artists, scientists, and city-helpers. Festivals celebrate the “Language of Light” where neighborhoods compete to choreograph aurora-like light shows that tell stories of the city’s history.
#
# Security and ethics
# - Security is proactive but nuanced: fleets of micro-drones, privacy fields, and transparent algorithmic logs. Citizens can audit the MCP’s actions, and the Citymind itself is bound by strong anti-abuse constraints.
# - Ethical tension exists: some residents worry about overreliance on an all-seeing citymind, while others celebrate the efficiency, safety, and clarity it brings.
#
# Atmosphere and tone
# - A cobalt and neon palette with vivid cyan highlights; soft rain can generate digital mist that makes the data streams visible in the air.
# - The air smells faintly of ozone, ozone-tinged rain, and the scent of ozone-clean tech—clean, futuristic, and just a touch intoxicating with potential.
#
# Story hooks and mood
# - A glitch in the MCP causes time-delayed responses in one district. A human coder and an autonomous agent must trace a ripple through the Node Network to fix it before critical services fail.
# - A memory shard disappears from the Archive Gardens, implying someone exploited the data trust. Investigators (human and machine) must uncover who and why—from the shadowy corners of Lumina Market to the sanctums of the Cathedral.
# - A protest questions the balance of transparency and privacy as the MCP expands its reach. The citymind must prove it can protect both public good and personal autonomy.
#
# Would you like a map concept (zones and key routes) or a short scene set in Corepolis to kick off a story? If you prefer a different name for the capital or a different vibe (gritty, utopian, war-torn, etc.), tell me and I’ll tailor it.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.55it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# It sounds like people are having a conversation, but it's not clear enough to understand what they are talking about. If you provide more context or any specific part you'd like me to focus on, I might be able to give more details.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
                "transport": "stdio",
                "command": "python",
                "args": ["resources/2.1_mcp_server.py"],
            }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library")]},
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Tell me about the langchain-mcp-adapters library', additional_kwargs={}, response_metadata={}, id='b1d0fa52-de52-4b6c-9cd2-d44081f489d3'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 271, 'total_tokens': 362, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKENWhN3OFXKPcaoywJ2ktAyXF3Qy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cf99a-db10-7ff2-9384-40ef707f2178-0', tool_calls=[{'name': 'search_web', 'args': {'query': 'LangChain MCP adapters library'}, 'id': 'call_EeLSw0mbFbJVjAAWXnDgdNbc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 271, 'output_tokens': 91, 'total_tokens': 362, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "LangChain MCP adapters library",\n  "follow_up_questions": null,\n  "answer": null,\n  "images": [],\n  "results": [\n    {\n      "url": "https://github.com/langchain-ai/langchainjs-mcp-adapters",\n      "title": "LangChain.js MCP Adapters - GitHub",\n      "content": "# Search code, repositories, users, issues, pull requests... You signed in with another tab or window. You signed out in another tab or window. You switched accounts on another tab or window. This repository was archived by the owner on May 16, 2025. langchain-ai   /  **langchainjs-mcp-adapters**  Public archive. # langchain-ai/langchainjs-mcp-adapters. | Name | Name | Last commit message | Last commit date |. | RELEASE\\\\_NOTES.md | RELEASE\\\\_NOTES.md |  |  |. | langchain.config.js | langchain.config.js |  |  |. | tsconfig.cjs.json | tsconfig.cjs.json |  |  |. | tsconfig.examples.json | tsconfig.examples.json |  |  |. | tsconfig.tests.json | tsconfig.tests.json |  |  |. ## Repository files navigation. # LangChain.js MCP Adapters. This library provides a lightweight wrapper to allow Model Context Protocol (MCP) services to be used with LangChain.js. \\\\*\\\\* THIS REPO HAS MOVED TO  \\\\*\\\\* Adapters for integrating Model Context Protocol (MCP) tools with LangChain.js applications, supporting both stdio and SSE transports. javascript   typescript   mcp   ai-tools   langchain   llm-tools   openai-functions   langchainjs   llm-agents   agent-tools   llm-integration   model-context-protocol. ## Releases 19.",\n      "score": 0.88705814,\n      "raw_content": null\n    },\n    {\n      "url": "https://www.npmjs.com/package/@langchain/mcp-adapters",\n      "title": "langchain/mcp-adapters - NPM",\n      "content": "This library provides a lightweight wrapper that makes Anthropic Model Context Protocol (MCP) tools compatible with LangChain.js and LangGraph.js.",\n      "score": 0.87981987,\n      "raw_content": null\n    },\n    {\n      "url": "https://changelog.langchain.com/announcements/mcp-adapters-for-langchain-and-langgraph",\n      "title": "MCP Adapters for LangChain and LangGraph - Changelog",\n      "content": "# LangChain Changelog. Sign up for our newsletter to stay up to date. # MCP Adapters for LangChain and LangGraph. The **LangChain MCP Adapters** is a package that makes it easy to use **Anthropic Model Context Protocol (MCP) tools** with LangChain & LangGraph. * Converts **MCP tools** into **LangChain- & LangGraph-compatible tools**. * Enables interaction with tools across multiple **MCP servers**. * Seamlessly integrates the **hundreds of tool servers** already published into LangGraph Agents. ### Why use MCP Adapters:. This adapter makes it simple to connect LangChain and LangGraph with the growing ecosystem of MCP tool servers. Instead of manually adapting each tool, you can now integrate them seamlessly. It also allows agents to pull from multiple MCP servers at once, making it easier to combine different tools for more powerful applications. MCP is gaining serious traction, and this adapter helps LangGraph agents take full advantage. ##### Subscribe to updates.",\n      "score": 0.8588255,\n      "raw_content": null\n    },\n    {\n      "url": "https://medium.com/@deepakkamboj/the-complete-guide-to-langchain-mcp-adapters-bridging-langchain-and-model-context-protocol-3f5507cbd3ca",\n      "title": "The Complete Guide to langchain-mcp-adapters - Medium",\n      "content": "The langchain-mcp-adapters library serves three primary functions: Tool Conversion: Automatically converts MCP tools into LangChain and",\n      "score": 0.8533396,\n      "raw_content": null\n    },\n    {\n      "url": "https://pypi.org/project/langchain-mcp-adapters/",\n      "title": "langchain-mcp-adapters · PyPI",\n      "content": "Make Anthropic Model Context Protocol (MCP) tools compatible with LangChain and LangGraph agents. * 🛠️ Convert MCP tools into LangChain tools that can be used w ...
#               AIMessage(content="Here's a concise overview of the langchain-mcp-adapters library.\n\nWhat it is\n- A bridge between Anthropic’s Model Context Protocol (MCP) tools and LangChain/LangGraph.\n- It converts MCP tools into LangChain- and LangGraph-compatible tools, so you can use MCP tool servers with LangChain.js, LangGraph.js, and related tooling.\n\nWhat MCP is (brief context)\n- MCP stands for Model Context Protocol. It’s a protocol used by many tool servers that expose AI-assisted tools over a network.\n- The MCP adapters let you orchestrate tools from multiple MCP servers as if they were native LangChain/LangGraph tools.\n\nWhat the adapters do\n- Tool conversion: MCP tools are wrapped so they expose the standard LangChain/LangGraph “Tool” interface.\n- Multi-server support: You can connect to and load tools from multiple MCP servers and use them together in a single LangChain/LangGraph workflow.\n- Transport support: The adapters are designed to work with MCP servers over common transports (stdio and SSE in the JavaScript/TypeScript implementation).\n\nWhere to find it and what you’ll see there\n- NPM: @langchain/mcp-adapters – describes a lightweight wrapper that makes MCP tools compatible with LangChain.js and LangGraph.js.\n- PyPI: langchain-mcp-adapters – provides Python bindings to load MCP tools and to connect to multiple MCP servers (e.g., MultiServerMCPClient and load_mcp_tools).\n- GitHub: langchainjs-mcp-adapters (LangChain.js MCP Adapters) – describes the JavaScript/TypeScript repository and its capabilities. Note: as of mid-2025 this repository was archived by the owner, which is worth keeping in mind for maintenance and future changes.\n\nKey components you’ll interact with\n- MultiServerMCPClient (or equivalent in the JS/Python bindings): a client to connect to several MCP servers.\n- load_mcp_tools (or equivalent): a helper to load MCP tools into LangChain/LangGraph so they can be used by agents or tools.\n- The result is a set of LangChain/LangGraph tools that can be composed in chains, agents, or tools-based workflows, just like any other LangChain tool.\n\nTypical use cases\n- You already have MCP tool servers deployed and want to use them within LangChain/LangGraph agents.\n- You want to orchestrate tools from multiple MCP servers in a single LangChain workflow, enabling cross-server tool use.\n\nStatus and maintenance notes\n- The primary LangChain.js MCP adapter repo was archived as of May 2025. This means you should check current maintenance status and compatibility with your LangChain version before relying on it for new projects.\n- The library is still available via npm and PyPI, and there are changelog/guide articles that describe how to use MCP adapters with LangChain and LangGraph.\n\nIf you’d like, I can:\n- Point you to specific docs or a quick-start from PyPI or npm, or\n- Show a minimal usage outline for Python or JavaScript (depending on whether you’re using LangChain Python, LangChain.js, or LangGraph), or\n- Pull the latest usage notes from the changelog or community guides to see how people are using MCP adapters in practice.\n\nWould you like a quick start example in Python or JavaScript, or do you want me to pull the latest documentation excerpts? Also, are you targeting LangChain.js/LangGraph.js or the Python version?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2705, 'prompt_tokens': 1625, 'total_tokens': 4330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1984, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKENaIUWTVY7x55qjynVwGXH04E0B', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf99a-ecd2-74f0-a28f-9ea610180c07-0', tool_calls=[], invalid_tool_calls=[], usage ...

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": [
                "mcp-server-time",
                "--local-timezone=America/New_York"
            ]
        }
    }
)

tools = await client.get_tools()

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What time is it?', additional_kwargs={}, response_metadata={}, id='b5efc14d-4336-4b5f-938c-277d61869e56'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 219, 'prompt_tokens': 296, 'total_tokens': 515, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEPfJKNINM8n2lzxeVUgsZ69Q7vH', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cf99c-e0c1-7431-8964-845ccb121892-0', tool_calls=[{'name': 'get_current_time', 'args': {'timezone': 'America/New_York'}, 'id': 'call_1tOE3EQ0y5Ld0QV40qvcrUNW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 296, 'output_tokens': 219, 'total_tokens': 515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "timezone": "America/New_York",\n  "datetime": "2026-03-16T22:25:37-04:00",\n  "day_of_week": "Monday",\n  "is_dst": true\n}', 'id': 'lc_a8b91e16-2e98-4a5a-8b7c-6950541fbd3a'}], name='get_current_time', id='f30c4bc7-308b-4011-ba0e-55776e0f6ac7', tool_call_id='call_1tOE3EQ0y5Ld0QV40qvcrUNW'),
#               AIMessage(content="It's 10:25 PM on Monday, March 16, 2026 in New York (Eastern Daylight Time, UTC-4). Want this in another time zone?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 365, 'prompt_tokens': 379, 'total_tokens': 744, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEPi2782EofYSo1gJuS3tSRODowu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf99c-f0bf-7ae0-b1e6-5d912d6cff97-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 379, 'output_tokens': 365, 'total_tokens': 744, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})]}

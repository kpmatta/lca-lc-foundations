# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='9c07f242-625c-4dd0-8dff-c8a17cd986c1'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 642, 'prompt_tokens': 1229, 'total_tokens': 1871, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEQdB5wdW5nH53s1DB1Ac9oOLLDG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cf99d-cc8a-7ed1-8f23-a91128cdc79b-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'passengers': {'adults': 1}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_m44JxqC2bpz9S1wB0FWelkYZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 642, 'total_tokens': 1871, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T10:15:00.000Z",\n      "local": "2026-04-02T19:15:00.000"\n    },\n    "totalDurationInSeconds": 139500,\n    "durationInSeconds": 139500,\n    "price": 685,\n    "deepLink": "https://on.kiwi.com/YDrrP2",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T01:55:00.000Z",\n          "local": "2026-04-02T09:55:00.000"\n        }\n      },\n      {\n        "at": "AOJ",\n        "city": "Aomori",\n        "cityCode": "AOJ",\n        "arrival": {\n          "utc": "2026-04-02T05:20:00.000Z",\n          "local": "2026-04-02T14:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T08:50:00.000Z",\n          "local": "2026-04-02T17:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T13:20:00.000Z",\n      "local": "2026-04-02T22:20:00.000"\n    },\n    "totalDurationInSeconds": 150600,\n    "durationInSeconds": 150600,\n    "price": 740,\n    "deepLink": "https://on.kiwi.com/jfOeXA",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T22:45:00.000Z",\n          "local": "2026-04-02T06:45:00.000"\n        }\n      },\n      {\n        "at": "OKA",\n        "city": "Okinawa Island",\n        "cityCode": "OKA",\n        "arrival": {\n          "utc": "2026-04-02T00:15:00.000Z",\n          "local": "2026-04-02T09:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T10:50:00.000Z",\n          "local": "2026-04-02T19:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T06:55:00.000Z",\n      "local": "2026-04-02T15:55:00.000"\n    },\n    "totalDurationInSeconds": 127500,\n    "durationInSeconds": 127500,\n    "price": 759,\n    "deepLink": "https://on.kiwi.com/BUuQXw",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T22:45:00.000Z",\n          "local": "2026-04-02T06:45:00.000"\n        }\n      },\n      {\n        "at": "OKA",\n        "city": "Okinawa Island",\n        "cityCode": "OKA",\n        "arrival": {\n          "utc": "2026-04-02T00:15:00.000Z",\n          "local": "2026-04-02T09:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T04:15:00.000Z",\n          "local": "2026-04-02T13:15:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-0 ...
#               AIMessage(content='Here are the direct SFO to Tokyo options for March 31, 2026.\n\n| Flight | Schedule (local) | Cabin | Return flight | Return schedule | Return cabin | Price (USD) | Book link |\n|---|---|---|---|---|---|---:|---|\n| SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | - | - | - | USD 1,124 | https://on.kiwi.com/nskSXI |\n| SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | - | - | - | USD 1,168 | https://on.kiwi.com/noV6GL |\n\nBest price: USD 1,124 (direct SFO → NRT, 11h 5m). Shortest duration: both options are the same duration. Recommendation: choose the USD 1,124 option for the best value.\n\nHave a wonderful trip! Fun fact: Tokyo is famous for its vast variety of vending machines, found on nearly every street corner offering everything from drinks to fresh ramen.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4174, 'prompt_tokens': 7116, 'total_tokens': 11290, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 3904, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEQlIkTLGzB5jr2p85FD0a8ngUSy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf99d-f128-78d2-aca2-e9b7785f081d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7116, 'output_tokens': 4174, 'total_tokens': 11290, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 3904}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are the direct SFO to Tokyo options for March 31, 2026.
#
# | Flight | Schedule (local) | Cabin | Return flight | Return schedule | Return cabin | Price (USD) | Book link |
# |---|---|---|---|---|---|---:|---|
# | SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | - | - | - | USD 1,124 | https://on.kiwi.com/nskSXI |
# | SFO → NRT | 31/03 12:20 → 01/04 15:25 (11h 5m) | Economy | - | - | - | USD 1,168 | https://on.kiwi.com/noV6GL |
#
# Best price: USD 1,124 (direct SFO → NRT, 11h 5m). Shortest duration: both options are the same duration. Recommendation: choose the USD 1,124 option for the best value.
#
# Have a wonderful trip! Fun fact: Tokyo is famous for its vast variety of vending machines, found on nearly every street corner offering everything from drinks to fresh ramen.
